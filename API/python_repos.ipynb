# %%
import requests

url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

response_dict = r.json()
print(f"Total repositories: {response_dict['total_count']}")
      
repo_dicts = response_dict['items']
print(f"Repositories returned: {len(repo_dicts)}")
      
repo_dict = repo_dicts[0]
print(f"\nKeys: {len(repo_dict)}")
for key in sorted(repo_dict.keys()):
    print(key)
# Out:
# Status code: 200
# Total repositories: 7848606
# Repositories returned: 30
#
# Keys: 80
# allow_forking
# archive_url
# archived
# assignees_url
# blobs_url
# branches_url
# clone_url
# collaborators_url
# comments_url
# commits_url
# compare_url
# contents_url
# contributors_url
# created_at
# default_branch
# deployments_url
# description
# disabled
# downloads_url
# events_url
# fork
# forks
# forks_count
# forks_url
# full_name
# git_commits_url
# git_refs_url
# git_tags_url
# git_url
# has_discussions
# has_downloads
# has_issues
# has_pages
# has_projects
# has_wiki
# homepage
# hooks_url
# html_url
# id
# is_template
# issue_comment_url
# issue_events_url
# issues_url
# keys_url
# labels_url
# language
# languages_url
# license
# merges_url
# milestones_url
# mirror_url
# name
# node_id
# notifications_url
# open_issues
# open_issues_count
# owner
# private
# pulls_url
# pushed_at
# releases_url
# score
# size
# ssh_url
# stargazers_count
# stargazers_url
# statuses_url
# subscribers_url
# subscription_url
# svn_url
# tags_url
# teams_url
# topics
# trees_url
# updated_at
# url
# visibility
# watchers
# watchers_count
# web_commit_signoff_required

# %%
import requests

url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

response_dict = r.json()
print(f"Total repositories: {response_dict['total_count']}")
      
repo_dicts = response_dict['items']
print(f"Repositories returned: {len(repo_dicts)}")
      
repo_dict = repo_dicts[0]
print("\nSelected information about first repository:")
print(f"Name: {repo_dict['name']}")
print(f"Owner: {repo_dict['owner']['login']}")
print(f"Stars: {repo_dict['stargazers_count']}")
print(f"Repository: {repo_dict['html_url']}")
print(f"Created: {repo_dict['created_at']}")
print(f"Updated: {repo_dict['updated_at']}")
print(f"Description: {repo_dict['description']}")
# Out:
# Status code: 200
# Total repositories: 8512216
# Repositories returned: 30
#
# Selected information about first repository:
# Name: system-design-primer
# Owner: donnemartin
# Stars: 210619
# Repository: https://github.com/donnemartin/system-design-primer
# Created: 2017-02-26T16:15:28Z
# Updated: 2023-02-06T13:39:37Z
# Description: Learn how to design large-scale systems. Prep for the system design interview.  Includes Anki flashcards.

# %%
import requests

url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

response_dict = r.json()
print(f"Total repositories: {response_dict['total_count']}")
      
repo_dicts = response_dict['items']
print(f"Repositories returned: {len(repo_dicts)}")
      

print("\nSelected information about each repository:")    
for repo_dict in repo_dicts:
    
    print(f"Name: {repo_dict['name']}")
    print(f"Owner: {repo_dict['owner']['login']}")
    print(f"Stars: {repo_dict['stargazers_count']}")
    print(f"Repository: {repo_dict['html_url']}")
    print(f"Created: {repo_dict['created_at']}")
    print(f"Updated: {repo_dict['updated_at']}")
    print(f"Description: {repo_dict['description']}")
    print('.')
# Out:
# Status code: 200
# Total repositories: 8743973
# Repositories returned: 30
#
# Selected information about each repository:
# Name: Python-100-Days
# Owner: jackfrued
# Stars: 130216
# Repository: https://github.com/jackfrued/Python-100-Days
# Created: 2018-03-01T16:05:52Z
# Updated: 2023-02-06T13:44:38Z
# Description: Python - 100天从新手到大师
# .
# Name: XX-Net
# Owner: XX-net
# Stars: 31651
# Repository: https://github.com/XX-net/XX-Net
# Created: 2015-01-15T09:35:51Z
# Updated: 2023-02-06T01:41:52Z
# Description: A proxy tool to bypass GFW.
# .
# Name: HanLP
# Owner: hankcs
# Stars: 27936
# Repository: https://github.com/hankcs/HanLP
# Created: 2014-10-09T06:36:16Z
# Updated: 2023-02-06T12:59:09Z
# Description: 中文分词 词性标注 命名实体识别 依存句法分析 成分句法分析 语义依存分析 语义角色标注 指代消解 风格转换 语义相似度 新词发现 关键词短语提取 自动摘要 文本分类聚类 拼音简繁转换 自然语言处理
# .
# Name: MockingBird
# Owner: babysor
# Stars: 26120
# Repository: https://github.com/babysor/MockingBird
# Created: 2021-08-07T03:53:39Z
# Updated: 2023-02-06T13:41:24Z
# Description: 🚀AI拟声: 5秒内克隆您的声音并生成任意语音内容 Clone a voice in 5 seconds to generate arbitrary speech in real-time
# .
# Name: ray
# Owner: ray-project
# Stars: 23937
# Repository: https://github.com/ray-project/ray
# Created: 2016-10-25T19:38:30Z
# Updated: 2023-02-06T13:54:45Z
# Description: Ray is a unified framework for scaling AI and Python applications. Ray consists of a core distributed runtime and a toolkit of libraries (Ray AIR) for accelerating ML workloads.
# .
# Name: ItChat
# Owner: littlecodersh
# Stars: 22822
# Repository: https://github.com/littlecodersh/ItChat
# Created: 2016-01-19T07:49:48Z
# Updated: 2023-02-06T13:26:38Z
# Description: A complete and graceful API for Wechat. 微信个人号接口、微信机器人及命令行微信，三十行即可自定义个人号机器人。
# .
# Name: hosts
# Owner: StevenBlack
# Stars: 22316
# Repository: https://github.com/StevenBlack/hosts
# Created: 2012-04-12T20:22:50Z
# Updated: 2023-02-06T13:29:22Z
# Description: 🔒 Consolidating and extending hosts files from several well-curated sources. Optionally pick extensions for porn, social media, and other categories.
# .
# Name: dash
# Owner: plotly
# Stars: 18043
# Repository: https://github.com/plotly/dash
# Created: 2015-04-10T01:53:08Z
# Updated: 2023-02-06T13:46:12Z
# Description: Data Apps & Dashboards for Python. No JavaScript Required.
# .
# Name: recommenders
# Owner: microsoft
# Stars: 14993
# Repository: https://github.com/microsoft/recommenders
# Created: 2018-09-19T10:06:07Z
# Updated: 2023-02-06T09:07:37Z
# Description: Best Practices on Recommendation Systems
# .
# Name: loguru
# Owner: Delgan
# Stars: 14024
# Repository: https://github.com/Delgan/loguru
# Created: 2017-08-15T17:22:32Z
# Updated: 2023-02-06T12:52:13Z
# Description: Python logging made (stupidly) simple
# .
# Name: aiohttp
# Owner: aio-libs
# Stars: 13231
# Repository: https://github.com/aio-libs/aiohttp
# Created: 2013-10-01T23:04:01Z
# Updated: 2023-02-05T18:11:40Z
# Description: Asynchronous HTTP client/server framework for asyncio and Python
# .
# Name: mackup
# Owner: lra
# Stars: 12917
# Repository: https://github.com/lra/mackup
# Created: 2013-04-06T19:22:54Z
# Updated: 2023-02-06T10:21:22Z
# Description: Keep your application settings in sync (OS X/Linux)
# .
# Name: awesome-oss-alternatives
# Owner: RunaCapital
# Stars: 12866
# Repository: https://github.com/RunaCapital/awesome-oss-alternatives
# Created: 2021-11-15T09:38:58Z
# Updated: 2023-02-06T03:26:36Z
# Description: Awesome list of open-source startup alternatives to well-known SaaS products 🚀
# .
# Name: searx
# Owner: searx
# Stars: 12511
# Repository: https://github.com/searx/searx
# Created: 2013-10-15T16:20:51Z
# Updated: 2023-02-06T09:54:31Z
# Description: Privacy-respecting metasearch engine
# .
# Name: learn_python3_spider
# Owner: wistbean
# Stars: 11594
# Repository: https://github.com/wistbean/learn_python3_spider
# Created: 2019-04-02T20:19:54Z
# Updated: 2023-02-06T10:10:24Z
# Description: python爬虫教程系列、从0到1学习python爬虫，包括浏览器抓包，手机APP抓包，如 fiddler、mitmproxy，各种爬虫涉及的模块的使用，如：requests、beautifulSoup、selenium、appium、scrapy等，以及IP代理，验证码识别，Mysql，MongoDB数据库的python使用，多线程多进程爬虫的使用，css 爬虫加密逆向破解，JS爬虫逆向，分布式爬虫，爬虫项目实战实例等
# .
# Name: Hitomi-Downloader
# Owner: KurtBestor
# Stars: 11507
# Repository: https://github.com/KurtBestor/Hitomi-Downloader
# Created: 2017-11-26T09:23:06Z
# Updated: 2023-02-06T13:09:31Z
# Description: :cake: Desktop utility to download images/videos/music/text from various websites, and more.
# .
# Name: PySimpleGUI
# Owner: PySimpleGUI
# Stars: 11178
# Repository: https://github.com/PySimpleGUI/PySimpleGUI
# Created: 2018-07-11T18:28:58Z
# Updated: 2023-02-06T11:21:42Z
# Description: Launched in 2018. It's 2023 and PySimpleGUI is actively developed & supported. Create complex windows simply. Supports tkinter, Qt, WxPython, Remi (in browser). Create GUI applications trivially with a full set of widgets. Multi-Window applications are also simple. 3.4 to 3.11 supported. 325+ Demo programs & Cookbook for rapid start. Extensive docs
# .
# Name: awesome-aws
# Owner: donnemartin
# Stars: 11176
# Repository: https://github.com/donnemartin/awesome-aws
# Created: 2015-10-12T12:02:47Z
# Updated: 2023-02-06T06:55:15Z
# Description: A curated list of awesome Amazon Web Services (AWS) libraries, open source repos, guides, blogs, and other resources.  Featuring the Fiery Meter of AWSome.
# .
# Name: redis-py
# Owner: redis
# Stars: 11129
# Repository: https://github.com/redis/redis-py
# Created: 2009-11-06T10:22:26Z
# Updated: 2023-02-06T09:59:08Z
# Description: Redis Python Client
# .
# Name: Mailpile
# Owner: mailpile
# Stars: 8686
# Repository: https://github.com/mailpile/Mailpile
# Created: 2011-10-30T23:45:22Z
# Updated: 2023-02-05T23:02:13Z
# Description: A free & open modern, fast email client with user-friendly encryption and privacy features
# .
# Name: wait-for-it
# Owner: vishnubob
# Stars: 8374
# Repository: https://github.com/vishnubob/wait-for-it
# Created: 2016-02-02T17:06:22Z
# Updated: 2023-02-05T18:35:45Z
# Description: Pure bash script to test and wait on the availability of a TCP host and port
# .
# Name: ColossalAI
# Owner: hpcaitech
# Stars: 8262
# Repository: https://github.com/hpcaitech/ColossalAI
# Created: 2021-10-28T16:19:44Z
# Updated: 2023-02-06T13:45:52Z
# Description: Colossal-AI: A Unified Deep Learning System for Big Model Era
# .
# Name: numba
# Owner: numba
# Stars: 8249
# Repository: https://github.com/numba/numba
# Created: 2012-03-08T11:12:43Z
# Updated: 2023-02-06T08:50:15Z
# Description: NumPy aware dynamic Python compiler using LLVM
# .
# Name: Python
# Owner: injetlee
# Stars: 8070
# Repository: https://github.com/injetlee/Python
# Created: 2016-06-23T15:15:23Z
# Updated: 2023-02-06T06:48:09Z
# Description: Python脚本。模拟登录知乎， 爬虫，操作excel，微信公众号，远程开机
# .
# Name: kedro
# Owner: kedro-org
# Stars: 8057
# Repository: https://github.com/kedro-org/kedro
# Created: 2019-04-18T10:29:56Z
# Updated: 2023-02-06T12:05:40Z
# Description: A Python framework for creating reproducible, maintainable and modular data science code.
# .
# Name: Reinforcement-learning-with-tensorflow
# Owner: MorvanZhou
# Stars: 7789
# Repository: https://github.com/MorvanZhou/Reinforcement-learning-with-tensorflow
# Created: 2017-05-06T03:01:31Z
# Updated: 2023-02-06T05:37:10Z
# Description: Simple Reinforcement learning tutorials, 莫烦Python 中文AI教学
# .
# Name: pysc2
# Owner: deepmind
# Stars: 7676
# Repository: https://github.com/deepmind/pysc2
# Created: 2017-07-25T18:16:57Z
# Updated: 2023-02-06T12:34:15Z
# Description: StarCraft II Learning Environment
# .
# Name: graphene
# Owner: graphql-python
# Stars: 7560
# Repository: https://github.com/graphql-python/graphene
# Created: 2015-09-24T09:18:18Z
# Updated: 2023-02-05T20:20:35Z
# Description: GraphQL framework for Python
# .
# Name: gitsome
# Owner: donnemartin
# Stars: 7364
# Repository: https://github.com/donnemartin/gitsome
# Created: 2016-04-23T03:08:21Z
# Updated: 2023-02-06T08:22:23Z
# Description: A supercharged Git/GitHub command line interface (CLI).  An official integration for GitHub and GitHub Enterprise: https://github.com/works-with/category/desktop-tools
# .
# Name: TensorLayer
# Owner: tensorlayer
# Stars: 7133
# Repository: https://github.com/tensorlayer/TensorLayer
# Created: 2016-06-07T15:55:16Z
# Updated: 2023-02-04T13:15:16Z
# Description: Deep Learning and Reinforcement Learning Library for Scientists and Engineers
# .
